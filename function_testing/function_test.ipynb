# %%
import pandas as pd 
df = pd.read_excel(r"C:\Users\ADMIN\OneDrive\Desktop\grade9.xlsx") 

df
# Out:
#     Position                  NAME  ENG  KISW  ...  C.A  SST  IRE  TOTAL
# 0          1         BWANA IDI ALI   59    66  ...   75   70   65    528
# 1          2     ABDIHAFID MOHAMUD   58    49  ...   70   50   59    495
# 2          3          BONAYA GWIYO   60    62  ...   54   56   56    484
# 3          4      ABDIQANI HUSSEIN   47    57  ...   50   56   60    430
# 4          5            YUSRA JUMA   58    61  ...   38   56   39    426
# 5          6           KOMORA SAID   39    56  ...   48   46   55    425
# 6          7         HAGERERA BUYA   57    66  ...   42   53   43    420
# 7          8          IDRISS JAMAA   43    53  ...   38   50   56    415
# 8          9  ABDIRAHMAN ABDI MIRE   46    43  ...   80   64   38    414
# 9         10           ABDALA SAID   46    57  ...   48   38   42    400
# 10        11           AHMED DUALE   43    43  ...   56   43   37    399
# 11        12          MALIKA HATIE   57    54  ...   48   58   43    396
# ...

# %%
from my_functions import cbc_report_generator
report = cbc_report_generator(df) 

report['CLOSING_DATE'] = '28-03-2026'
report['OPENING_DATE'] = '31-04-2026'

report
# Out:
#     Position                  NAME  ... CLOSING_DATE OPENING_DATE
# 0          1         BWANA IDI ALI  ...   28-03-2026   31-04-2026
# 1          2     ABDIHAFID MOHAMUD  ...   28-03-2026   31-04-2026
# 2          3          BONAYA GWIYO  ...   28-03-2026   31-04-2026
# 3          4      ABDIQANI HUSSEIN  ...   28-03-2026   31-04-2026
# 4          5            YUSRA JUMA  ...   28-03-2026   31-04-2026
# 5          6           KOMORA SAID  ...   28-03-2026   31-04-2026
# 6          7         HAGERERA BUYA  ...   28-03-2026   31-04-2026
# 7          8          IDRISS JAMAA  ...   28-03-2026   31-04-2026
# 8          9  ABDIRAHMAN ABDI MIRE  ...   28-03-2026   31-04-2026
# 9         10           ABDALA SAID  ...   28-03-2026   31-04-2026
# 10        11           AHMED DUALE  ...   28-03-2026   31-04-2026
# 11        12          MALIKA HATIE  ...   28-03-2026   31-04-2026
# 12        13   ABDINASIR ABDULLAHI  ...   28-03-2026   31-04-2026
# ...

# %%
report.to_csv('grade9Processed1.csv', index=False)
